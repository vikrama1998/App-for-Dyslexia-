# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5 import QtCore, QtGui, QtWidgets
import pandas as pd
from random import randint
import pyttsx3
from PyQt5.QtGui import QMovie
import csv
import os 
import string
import random
from PyQt5 import uic
from PyQt5.QtWidgets import QMessageBox,QWidget
class Ui_MainWindow(object):
    def setupUi(self,MainWindow):
        self.MainWindow = MainWindow
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(822, 621)
        font = QtGui.QFont()
        font.setStyleStrategy(QtGui.QFont.NoAntialias)
        MainWindow.setFont(font)
#         QtCore.QMetaObject.connectSlotsByName(MainWindow)
#         self.ui = uic.loadUi('main_window.ui')
#         self.ui.closeEvent = self.closeEvent
#         app.aboutToQuit.connect(self.closeEvent)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.gridLayout_2 = QtWidgets.QGridLayout(self.centralwidget)
        self.gridLayout_2.setContentsMargins(0, 0, 0, 0)
        self.gridLayout_2.setSpacing(0)
        self.gridLayout_2.setObjectName("gridLayout_2")
        self.verticalLayout_9 = QtWidgets.QVBoxLayout()
        self.verticalLayout_9.setSpacing(0)
        self.verticalLayout_9.setObjectName("verticalLayout_9")
        self.stackedWidget = QtWidgets.QStackedWidget(self.centralwidget)
#         self.stackedWidget.setStyleSheet("\n"
# "background-color: rgb(224, 187, 255);")
        self.stackedWidget.setStyleSheet(".QWidget{border-image : url(lightbackground.jpg);}")
        self.stackedWidget.setObjectName("stackedWidget")
        self.page = QtWidgets.QWidget()
        self.page.setObjectName("page")
        self.gridLayout = QtWidgets.QGridLayout(self.page)
        self.gridLayout.setObjectName("gridLayout")
        self.horizontalLayout_12 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_12.setSpacing(0)
        self.horizontalLayout_12.setObjectName("horizontalLayout_12")
        spacerItem = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_12.addItem(spacerItem)
        self.b2homeButton = QtWidgets.QPushButton(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.b2homeButton.sizePolicy().hasHeightForWidth())
        self.b2homeButton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(9)
        font.setBold(True)
        font.setWeight(75)
        self.b2homeButton.setFont(font)
        self.b2homeButton.setStyleSheet("background-color: rgb(255, 88, 91);")
        self.b2homeButton.setObjectName("b2homeButton")
        #       edited
        self.b2homeButton.clicked.connect(self.ctwback2home)
        self.horizontalLayout_12.addWidget(self.b2homeButton)
        spacerItem1 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_12.addItem(spacerItem1)
        self.gridLayout.addLayout(self.horizontalLayout_12, 2, 0, 1, 1)
        self.verticalLayout_8 = QtWidgets.QVBoxLayout()
        self.verticalLayout_8.setSpacing(0)
        self.verticalLayout_8.setObjectName("verticalLayout_8")
        self.horizontalLayout_9 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_9.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_9.setObjectName("horizontalLayout_9")
        self.horizontalLayout_4 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_4.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_4.setSpacing(0)
        self.horizontalLayout_4.setObjectName("horizontalLayout_4")
        self.qnumLabel = QtWidgets.QLabel(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.qnumLabel.sizePolicy().hasHeightForWidth())
        self.qnumLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Swis721 BT")
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.qnumLabel.setFont(font)
        self.qnumLabel.setObjectName("qnumLabel")
        self.qnumLabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.horizontalLayout_4.addWidget(self.qnumLabel)
        spacerItem2 = QtWidgets.QSpacerItem(150, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_4.addItem(spacerItem2)
        self.ctwtitleLabel = QtWidgets.QLabel(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctwtitleLabel.sizePolicy().hasHeightForWidth())
        self.ctwtitleLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(24)
        font.setBold(True)
        font.setWeight(75)
        self.ctwtitleLabel.setFont(font)
        self.ctwtitleLabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.ctwtitleLabel.setObjectName("ctwtitleLabel")
        self.horizontalLayout_4.addWidget(self.ctwtitleLabel)
        spacerItem3 = QtWidgets.QSpacerItem(150, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_4.addItem(spacerItem3)
        self.scoreLabel = QtWidgets.QLabel(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.scoreLabel.sizePolicy().hasHeightForWidth())
        self.scoreLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(10)
        font.setBold(True)
        font.setWeight(75)
        self.scoreLabel.setFont(font)
        self.scoreLabel.setObjectName("scoreLabel")
        self.scoreLabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.horizontalLayout_4.addWidget(self.scoreLabel)
        self.horizontalLayout_9.addLayout(self.horizontalLayout_4)
        self.verticalLayout_8.addLayout(self.horizontalLayout_9)
        self.verticalLayout_7 = QtWidgets.QVBoxLayout()
        self.verticalLayout_7.setSpacing(0)
        self.verticalLayout_7.setObjectName("verticalLayout_7")
        self.horizontalLayout_8 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_8.setContentsMargins(-1, 8, -1, -1)
        self.horizontalLayout_8.setSpacing(0)
        self.horizontalLayout_8.setObjectName("horizontalLayout_8")
        self.verticalLayout_3 = QtWidgets.QVBoxLayout()
        self.verticalLayout_3.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.verticalLayout_3.setContentsMargins(-1, 0, -1, 0)
        self.verticalLayout_3.setSpacing(0)
        self.verticalLayout_3.setObjectName("verticalLayout_3")
        self.horizontalLayout = QtWidgets.QHBoxLayout()
        self.horizontalLayout.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout.setObjectName("horizontalLayout")
        spacerItem4 = QtWidgets.QSpacerItem(50, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout.addItem(spacerItem4)
        self.playButton = QtWidgets.QPushButton(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.playButton.sizePolicy().hasHeightForWidth())
        self.playButton.setSizePolicy(sizePolicy)
        self.playButton.setStyleSheet("background-color: rgb(255, 58, 52);")
        self.playButton.setText("")
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("play.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.playButton.setIcon(icon)
        self.playButton.setIconSize(QtCore.QSize(50, 50))
        self.playButton.setFlat(True)
        self.playButton.setObjectName("playButton")
        self.playButton.setToolTip("Play")
        #         edited
        self.playButton.clicked.connect(self.play)
        
        self.horizontalLayout.addWidget(self.playButton)
        spacerItem5 = QtWidgets.QSpacerItem(74, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout.addItem(spacerItem5)
        self.verticalLayout_3.addLayout(self.horizontalLayout)
        self.verticalLayout = QtWidgets.QVBoxLayout()
        self.verticalLayout.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.verticalLayout.setObjectName("verticalLayout")
        self.horizontalLayout_3 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_3.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_3.setObjectName("horizontalLayout_3")
        spacerItem6 = QtWidgets.QSpacerItem(100, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_3.addItem(spacerItem6)
        self.answerLineedit = QtWidgets.QLineEdit(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.answerLineedit.sizePolicy().hasHeightForWidth())
        self.answerLineedit.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(14)
        self.answerLineedit.setFont(font)
        self.answerLineedit.setStyleSheet("background-color: rgb(177, 255, 125);")
        self.answerLineedit.setObjectName("answerLineedit")
        self.horizontalLayout_3.addWidget(self.answerLineedit)
        spacerItem7 = QtWidgets.QSpacerItem(18, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_3.addItem(spacerItem7)
        self.verticalLayout.addLayout(self.horizontalLayout_3)
        spacerItem8 = QtWidgets.QSpacerItem(20, 20, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout.addItem(spacerItem8)
        self.verticalLayout_3.addLayout(self.verticalLayout)
        self.verticalLayout_2 = QtWidgets.QVBoxLayout()
        self.verticalLayout_2.setObjectName("verticalLayout_2")
        self.horizontalLayout_2 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_2.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_2.setObjectName("horizontalLayout_2")
        spacerItem9 = QtWidgets.QSpacerItem(100, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_2.addItem(spacerItem9)
        self.ctwcheckButton = QtWidgets.QPushButton(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctwcheckButton.sizePolicy().hasHeightForWidth())
        self.ctwcheckButton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Vani")
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.ctwcheckButton.setFont(font)
        self.ctwcheckButton.setStyleSheet("background-color: rgb(85, 170, 0);")
        self.ctwcheckButton.setObjectName("ctwcheckButton")
        #         edited
        self.ctwcheckButton.clicked.connect(self.check)
        
        self.horizontalLayout_2.addWidget(self.ctwcheckButton)
        spacerItem10 = QtWidgets.QSpacerItem(68, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_2.addItem(spacerItem10)
        self.ctwnextButton = QtWidgets.QPushButton(self.page)
        font = QtGui.QFont()
        font.setFamily("Vani")
        font.setPointSize(11)
        font.setBold(True)
        font.setItalic(False)
        font.setUnderline(False)
        font.setWeight(75)
        font.setStrikeOut(False)
        self.ctwnextButton.setFont(font)
        self.ctwnextButton.setStyleSheet("background-color: rgb(85, 170, 0);")
        self.ctwnextButton.setObjectName("ctwnextButton")
        #         edited
        self.ctwnextButton.clicked.connect(self.ctwnext)
        
        self.horizontalLayout_2.addWidget(self.ctwnextButton)
        self.verticalLayout_2.addLayout(self.horizontalLayout_2)
        spacerItem11 = QtWidgets.QSpacerItem(20, 39, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_2.addItem(spacerItem11)
        self.verticalLayout_3.addLayout(self.verticalLayout_2)
        self.horizontalLayout_8.addLayout(self.verticalLayout_3)
        self.verticalLayout_6 = QtWidgets.QVBoxLayout()
        self.verticalLayout_6.setSpacing(0)
        self.verticalLayout_6.setObjectName("verticalLayout_6")
        self.horizontalLayout_7 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_7.setSizeConstraint(QtWidgets.QLayout.SetMinimumSize)
        self.horizontalLayout_7.setSpacing(0)
        self.horizontalLayout_7.setObjectName("horizontalLayout_7")
        spacerItem12 = QtWidgets.QSpacerItem(10, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_7.addItem(spacerItem12)
        self.qmarkimageLabel = QtWidgets.QLabel(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.qmarkimageLabel.sizePolicy().hasHeightForWidth())
        self.qmarkimageLabel.setSizePolicy(sizePolicy)
        self.qmarkimageLabel.setText("")
        self.qmarkimageLabel.setPixmap(QtGui.QPixmap("F:/Downloads/Webp.net-resizeimage (3).png"))
        self.qmarkimageLabel.setObjectName("qmarkimageLabel")
        self.horizontalLayout_7.addWidget(self.qmarkimageLabel)
        spacerItem13 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_7.addItem(spacerItem13)
        self.verticalLayout_6.addLayout(self.horizontalLayout_7)
        spacerItem14 = QtWidgets.QSpacerItem(20, 26, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_6.addItem(spacerItem14)
        self.horizontalLayout_8.addLayout(self.verticalLayout_6)
        self.verticalLayout_7.addLayout(self.horizontalLayout_8)
        self.verticalLayout_4 = QtWidgets.QVBoxLayout()
        self.verticalLayout_4.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.verticalLayout_4.setContentsMargins(-1, -1, -1, 0)
        self.verticalLayout_4.setSpacing(0)
        self.verticalLayout_4.setObjectName("verticalLayout_4")
        self.horizontalLayout_5 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_5.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_5.setObjectName("horizontalLayout_5")
        spacerItem15 = QtWidgets.QSpacerItem(2, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_5.addItem(spacerItem15)
        self.resultLabel = QtWidgets.QLabel(self.page)
        font = QtGui.QFont()
        font.setFamily("Raavi")
        font.setPointSize(10)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(9)
        self.resultLabel.setFont(font)
        self.resultLabel.setStyleSheet("font: 75 10pt \"Raavi\";\n"
"font: 10pt \"SWRomnt\";\n"
"color: rgb(255, 255, 255);")
        self.resultLabel.setAlignment(QtCore.Qt.AlignCenter)
        self.resultLabel.setObjectName("resultLabel")
        self.horizontalLayout_5.addWidget(self.resultLabel)
        spacerItem16 = QtWidgets.QSpacerItem(32, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_5.addItem(spacerItem16)
        self.verticalLayout_4.addLayout(self.horizontalLayout_5)
        spacerItem17 = QtWidgets.QSpacerItem(20, 2, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_4.addItem(spacerItem17)
        spacerItem18 = QtWidgets.QSpacerItem(20, 15, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_4.addItem(spacerItem18)
        self.horizontalLayout_6 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_6.setSpacing(10)
        self.horizontalLayout_6.setObjectName("horizontalLayout_6")
        spacerItem19 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_6.addItem(spacerItem19)
        self.indicatorLabel = QtWidgets.QLabel(self.page)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.indicatorLabel.sizePolicy().hasHeightForWidth())
        self.indicatorLabel.setSizePolicy(sizePolicy)
        self.indicatorLabel.setText("")
        self.indicatorLabel.setPixmap(QtGui.QPixmap("E:/images clipart/thumbsdown_mod.gif"))
        self.indicatorLabel.setScaledContents(True)
        self.indicatorLabel.setAlignment(QtCore.Qt.AlignCenter)
        self.indicatorLabel.setObjectName("indicatorLabel")
        self.horizontalLayout_6.addWidget(self.indicatorLabel)
        spacerItem20 = QtWidgets.QSpacerItem(120, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_6.addItem(spacerItem20)
        self.verticalLayout_4.addLayout(self.horizontalLayout_6)
        self.verticalLayout_7.addLayout(self.verticalLayout_4)
        self.verticalLayout_8.addLayout(self.verticalLayout_7)
        self.gridLayout.addLayout(self.verticalLayout_8, 0, 0, 1, 1)
        spacerItem21 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Expanding)
        self.gridLayout.addItem(spacerItem21, 1, 0, 1, 1)
        self.stackedWidget.addWidget(self.page)
        self.page_3 = QtWidgets.QWidget()
        self.page_3.setObjectName("page_3")
        self.gridLayout_5 = QtWidgets.QGridLayout(self.page_3)
        self.gridLayout_5.setObjectName("gridLayout_5")
        self.verticalLayout_14 = QtWidgets.QVBoxLayout()
        self.verticalLayout_14.setObjectName("verticalLayout_14")
        self.horizontalLayout_16 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_16.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_16.setObjectName("horizontalLayout_16")
        spacerItem22 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_16.addItem(spacerItem22)
        self.stftopicLabel = QtWidgets.QLabel(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stftopicLabel.sizePolicy().hasHeightForWidth())
        self.stftopicLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(24)
        self.stftopicLabel.setFont(font)
        self.stftopicLabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.stftopicLabel.setObjectName("stftopicLabel")
        self.horizontalLayout_16.addWidget(self.stftopicLabel)
        spacerItem23 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_16.addItem(spacerItem23)
        self.verticalLayout_14.addLayout(self.horizontalLayout_16)
        self.horizontalLayout_19 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_19.setObjectName("horizontalLayout_19")
        spacerItem24 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_19.addItem(spacerItem24)
        self.verticalLayout_10 = QtWidgets.QVBoxLayout()
        self.verticalLayout_10.setObjectName("verticalLayout_10")
        self.stfqnumLabel = QtWidgets.QLabel(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stfqnumLabel.sizePolicy().hasHeightForWidth())
        self.stfqnumLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(11)
        self.stfqnumLabel.setFont(font)
        self.stfqnumLabel.setAlignment(QtCore.Qt.AlignCenter)
        self.stfqnumLabel.setObjectName("stfqnumLabel")
        self.stfqnumLabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.verticalLayout_10.addWidget(self.stfqnumLabel)
        spacerItem25 = QtWidgets.QSpacerItem(20, 70, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_10.addItem(spacerItem25)
        self.horizontalLayout_19.addLayout(self.verticalLayout_10)
        self.stfimageLabel = QtWidgets.QLabel(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stfimageLabel.sizePolicy().hasHeightForWidth())
        self.stfimageLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.stfimageLabel.setFont(font)
        self.stfimageLabel.setText("")
        self.stfimageLabel.setPixmap(QtGui.QPixmap("E:/images clipart/linoness1.jpg"))
        self.stfimageLabel.setScaledContents(True)
        self.stfimageLabel.setObjectName("stfimageLabel")
        self.horizontalLayout_19.addWidget(self.stfimageLabel)
        self.verticalLayout_11 = QtWidgets.QVBoxLayout()
        self.verticalLayout_11.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.verticalLayout_11.setObjectName("verticalLayout_11")
        spacerItem26 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_11.addItem(spacerItem26)
        self.stfhintButton = QtWidgets.QPushButton(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stfhintButton.sizePolicy().hasHeightForWidth())
        self.stfhintButton.setSizePolicy(sizePolicy)
        self.stfhintButton.setText("")
        icon1 = QtGui.QIcon()
        icon1.addPixmap(QtGui.QPixmap("E:/images clipart/lighthint.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.stfhintButton.setIcon(icon1)
        self.stfhintButton.setIconSize(QtCore.QSize(30, 30))
        self.stfhintButton.setFlat(True)
        self.stfhintButton.setObjectName("stfhintButton")
#         edited
        self.stfhintButton.setToolTip("Hint")
        self.stfhintButton.clicked.connect(self.stfhint)
        self.verticalLayout_11.addWidget(self.stfhintButton)
        spacerItem27 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_11.addItem(spacerItem27)
        self.horizontalLayout_19.addLayout(self.verticalLayout_11)
        self.verticalLayout_12 = QtWidgets.QVBoxLayout()
        self.verticalLayout_12.setObjectName("verticalLayout_12")
        spacerItem28 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_12.addItem(spacerItem28)
        self.stfLineedit = QtWidgets.QLineEdit(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stfLineedit.sizePolicy().hasHeightForWidth())
        self.stfLineedit.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(14)
        self.stfLineedit.setFont(font)
        self.stfLineedit.setObjectName("stfLineedit")
        self.verticalLayout_12.addWidget(self.stfLineedit)
        
        self.horizontalLayout_17 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_17.setObjectName("horizontalLayout_17")
        spacerItem29 = QtWidgets.QSpacerItem(120, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_17.addItem(spacerItem29)
        self.pushButton = QtWidgets.QPushButton(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.pushButton.sizePolicy().hasHeightForWidth())
        self.pushButton.setSizePolicy(sizePolicy)
        self.pushButton.setText("")
        icon2 = QtGui.QIcon()
        icon2.addPixmap(QtGui.QPixmap("E:/images clipart/back.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.pushButton.setIcon(icon2)
        self.pushButton.setIconSize(QtCore.QSize(16, 16))
        self.pushButton.setObjectName("pushButton")
#         edited
        self.pushButton.setToolTip('Backspace')
        self.pushButton.clicked.connect(self.backspace)
        self.horizontalLayout_17.addWidget(self.pushButton)
        self.verticalLayout_12.addLayout(self.horizontalLayout_17)
        
        spacerItem29 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_12.addItem(spacerItem29)
        self.horizontalLayout_19.addLayout(self.verticalLayout_12)
        self.verticalLayout_13 = QtWidgets.QVBoxLayout()
        self.verticalLayout_13.setObjectName("verticalLayout_13")
        self.stfscoreLabel = QtWidgets.QLabel(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stfscoreLabel.sizePolicy().hasHeightForWidth())
        self.stfscoreLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Impact")
        font.setPointSize(11)
        font.setBold(False)
        font.setWeight(50)
        self.stfscoreLabel.setFont(font)
        self.stfscoreLabel.setObjectName("stfscoreLabel")
        self.stfscoreLabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.verticalLayout_13.addWidget(self.stfscoreLabel)
        spacerItem30 = QtWidgets.QSpacerItem(20, 100, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_13.addItem(spacerItem30)
        self.horizontalLayout_19.addLayout(self.verticalLayout_13)
    
        self.verticalLayout_15 = QtWidgets.QVBoxLayout()
        self.verticalLayout_15.setObjectName("verticalLayout_15")
        spacerItem32 = QtWidgets.QSpacerItem(20, 35, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_15.addItem(spacerItem32)
        self.horizontalLayout_18 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_18.setObjectName("horizontalLayout_18")
        self.stfindicator = QtWidgets.QLabel(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stfindicator.sizePolicy().hasHeightForWidth())
        self.stfindicator.setSizePolicy(sizePolicy)
        self.stfindicator.setText("")
        self.stfindicator.setPixmap(QtGui.QPixmap("E:/images clipart/thumbsdown_mod.gif"))
        self.stfindicator.setObjectName("stfindicator")
        self.stfindicator.setToolTip('Indicator')
        self.horizontalLayout_18.addWidget(self.stfindicator)
        self.verticalLayout_15.addLayout(self.horizontalLayout_18)
        self.horizontalLayout_21 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_21.setObjectName("horizontalLayout_21")
        self.label = QtWidgets.QLabel(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.label.sizePolicy().hasHeightForWidth())
        self.label.setSizePolicy(sizePolicy)
        self.label.setAlignment(QtCore.Qt.AlignCenter)
        self.label.setObjectName("label")
        self.label.setStyleSheet("color: rgb(255, 255, 255);")
        self.horizontalLayout_21.addWidget(self.label)
        self.verticalLayout_15.addLayout(self.horizontalLayout_21)
        self.horizontalLayout_19.addLayout(self.verticalLayout_15)
        spacerItem33 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_19.addItem(spacerItem33)
        self.verticalLayout_14.addLayout(self.horizontalLayout_19)
        self.horizontalLayout_20 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_20.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_20.setObjectName("horizontalLayout_20")
        spacerItem34 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_20.addItem(spacerItem34)
        self.ptfcheckButton = QtWidgets.QPushButton(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ptfcheckButton.sizePolicy().hasHeightForWidth())

        self.ptfcheckButton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Vani")
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.ptfcheckButton.setFont(font)
        self.ptfcheckButton.setStyleSheet("background-color: rgb(85, 170, 0);")
        self.ptfcheckButton.setObjectName("ptfcheckButton")
#         edited
        self.ptfcheckButton.clicked.connect(self.stfcheck)
    
        self.horizontalLayout_20.addWidget(self.ptfcheckButton)
        spacerItem33 = QtWidgets.QSpacerItem(75, 0, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_20.addItem(spacerItem33)
        self.stfnextButton = QtWidgets.QPushButton(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.stfnextButton.sizePolicy().hasHeightForWidth())
        self.stfnextButton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Vani")
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.stfnextButton.setFont(font)
        self.stfnextButton.setStyleSheet("background-color: rgb(85, 170, 0);")
        self.stfnextButton.setObjectName("stfnextButton")
        self.stfnextButton.clicked.connect(self.stfprogress)
        self.horizontalLayout_20.addWidget(self.stfnextButton)
        spacerItem34 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_20.addItem(spacerItem34)
        self.verticalLayout_14.addLayout(self.horizontalLayout_20)
        self.frame_2 = QtWidgets.QFrame(self.page_3)
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.frame_2.setStyleSheet("background-color: rgb(113, 113, 113);")
        self.gridLayout_4 = QtWidgets.QGridLayout(self.frame_2)
        self.gridLayout_4.setObjectName("gridLayout_4")
        self.p24 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p24.sizePolicy().hasHeightForWidth())
        self.p24.setSizePolicy(sizePolicy)
        self.p24.setText("")
        icon2 = QtGui.QIcon()
        icon2.addPixmap(QtGui.QPixmap("E:/images clipart/letters/letter a.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.p24.setIcon(icon2)
        self.p24.setIconSize(QtCore.QSize(40, 40))
        self.p24.setFlat(True)
        self.p24.setObjectName("p24")
        self.gridLayout_4.addWidget(self.p24, 0, 2, 2, 2)
        self.p2 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p2.sizePolicy().hasHeightForWidth())
        self.p2.setSizePolicy(sizePolicy)
        self.p2.setText("")
        self.p2.setIcon(icon2)
        self.p2.setIconSize(QtCore.QSize(40, 40))
        self.p2.setFlat(True)
        self.p2.setObjectName("p2")
        self.gridLayout_4.addWidget(self.p2, 0, 5, 3, 2)
        self.p6 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p6.sizePolicy().hasHeightForWidth())
        self.p6.setSizePolicy(sizePolicy)
        self.p6.setText("")
        self.p6.setIcon(icon2)
        self.p6.setIconSize(QtCore.QSize(40, 40))
        self.p6.setFlat(True)
        self.p6.setObjectName("p6")
        self.gridLayout_4.addWidget(self.p6, 0, 10, 1, 2)
        self.p12 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p12.sizePolicy().hasHeightForWidth())
        self.p12.setSizePolicy(sizePolicy)
        self.p12.setText("")
        self.p12.setIcon(icon2)
        self.p12.setIconSize(QtCore.QSize(40, 40))
        self.p12.setFlat(True)
        self.p12.setObjectName("p12")
        self.gridLayout_4.addWidget(self.p12, 0, 13, 4, 2)
        self.p21 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p21.sizePolicy().hasHeightForWidth())
        self.p21.setSizePolicy(sizePolicy)
        self.p21.setText("")
        self.p21.setIcon(icon2)
        self.p21.setIconSize(QtCore.QSize(40, 40))
        self.p21.setFlat(True)
        self.p21.setObjectName("p21")
        self.gridLayout_4.addWidget(self.p21, 0, 16, 4, 1)
        self.p20 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p20.sizePolicy().hasHeightForWidth())
        self.p20.setSizePolicy(sizePolicy)
        self.p20.setText("")
        self.p20.setIcon(icon2)
        self.p20.setIconSize(QtCore.QSize(40, 40))
        self.p20.setFlat(True)
        self.p20.setObjectName("p20")
        self.gridLayout_4.addWidget(self.p20, 0, 17, 2, 1)
        self.p11 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p11.sizePolicy().hasHeightForWidth())
        self.p11.setSizePolicy(sizePolicy)
        self.p11.setText("")
        self.p11.setIcon(icon2)
        self.p11.setIconSize(QtCore.QSize(40, 40))
        self.p11.setFlat(True)
        self.p11.setObjectName("p11")
        self.gridLayout_4.addWidget(self.p11, 1, 0, 3, 2)
        self.p23 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p23.sizePolicy().hasHeightForWidth())
        self.p23.setSizePolicy(sizePolicy)
        self.p23.setText("")
        self.p23.setIcon(icon2)
        self.p23.setIconSize(QtCore.QSize(40, 40))
        self.p23.setFlat(True)
        self.p23.setObjectName("p23")
        self.gridLayout_4.addWidget(self.p23, 1, 8, 3, 2)
        self.p29 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p29.sizePolicy().hasHeightForWidth())
        self.p29.setSizePolicy(sizePolicy)
        self.p29.setText("")
        self.p29.setIcon(icon2)
        self.p29.setIconSize(QtCore.QSize(40, 40))
        self.p29.setFlat(True)
        self.p29.setObjectName("p29")
        self.gridLayout_4.addWidget(self.p29, 2, 12, 3, 1)
        self.p17 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p17.sizePolicy().hasHeightForWidth())
        self.p17.setSizePolicy(sizePolicy)
        self.p17.setText("")
        self.p17.setIcon(icon2)
        self.p17.setIconSize(QtCore.QSize(40, 40))
        self.p17.setFlat(True)
        self.p17.setObjectName("p17")
        self.gridLayout_4.addWidget(self.p17, 2, 15, 3, 1)
        self.p1 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p1.sizePolicy().hasHeightForWidth())
        self.p1.setSizePolicy(sizePolicy)
        self.p1.setText("")
        self.p1.setIcon(icon2)
        self.p1.setIconSize(QtCore.QSize(40, 40))
        self.p1.setFlat(True)
        self.p1.setObjectName("p1")
        self.gridLayout_4.addWidget(self.p1, 3, 4, 3, 2)
        self.p10 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p10.sizePolicy().hasHeightForWidth())
        self.p10.setSizePolicy(sizePolicy)
        self.p10.setText("")
        self.p10.setIcon(icon2)
        self.p10.setIconSize(QtCore.QSize(40, 40))
        self.p10.setFlat(True)
        self.p10.setObjectName("p10")
        self.gridLayout_4.addWidget(self.p10, 3, 17, 3, 1)
        self.p18 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p18.sizePolicy().hasHeightForWidth())
        self.p18.setSizePolicy(sizePolicy)
        self.p18.setText("")
        self.p18.setIcon(icon2)
        self.p18.setIconSize(QtCore.QSize(40, 40))
        self.p18.setFlat(True)
        self.p18.setObjectName("p18")
        self.gridLayout_4.addWidget(self.p18, 4, 16, 3, 1)
        self.p3 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p3.sizePolicy().hasHeightForWidth())
        self.p3.setSizePolicy(sizePolicy)
        self.p3.setText("")
        self.p3.setIcon(icon2)
        self.p3.setIconSize(QtCore.QSize(40, 40))
        self.p3.setFlat(True)
        self.p3.setObjectName("p3")
        self.gridLayout_4.addWidget(self.p3, 5, 9, 3, 2)
        self.p31 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p31.sizePolicy().hasHeightForWidth())
        self.p31.setSizePolicy(sizePolicy)
        self.p31.setText("")
        self.p31.setIcon(icon2)
        self.p31.setIconSize(QtCore.QSize(40, 40))
        self.p31.setFlat(True)
        self.p31.setObjectName("p31")
        self.gridLayout_4.addWidget(self.p31, 6, 0, 3, 1)
        self.p16 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p16.sizePolicy().hasHeightForWidth())
        self.p16.setSizePolicy(sizePolicy)
        self.p16.setText("")
        self.p16.setIcon(icon2)
        self.p16.setIconSize(QtCore.QSize(40, 40))
        self.p16.setFlat(True)
        self.p16.setObjectName("p16")
        self.gridLayout_4.addWidget(self.p16, 6, 3, 3, 1)
        self.p26 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p26.sizePolicy().hasHeightForWidth())
        self.p26.setSizePolicy(sizePolicy)
        self.p26.setText("")
        self.p26.setIcon(icon2)
        self.p26.setIconSize(QtCore.QSize(40, 40))
        self.p26.setFlat(True)
        self.p26.setObjectName("p26")
        self.gridLayout_4.addWidget(self.p26, 6, 4, 3, 1)
        self.p4 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p4.sizePolicy().hasHeightForWidth())
        self.p4.setSizePolicy(sizePolicy)
        self.p4.setText("")
        self.p4.setIcon(icon2)
        self.p4.setIconSize(QtCore.QSize(40, 40))
        self.p4.setFlat(True)
        self.p4.setObjectName("p4")
        self.gridLayout_4.addWidget(self.p4, 6, 13, 3, 1)
        self.p22 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p22.sizePolicy().hasHeightForWidth())
        self.p22.setSizePolicy(sizePolicy)
        self.p22.setText("")
        self.p22.setIcon(icon2)
        self.p22.setIconSize(QtCore.QSize(40, 40))
        self.p22.setFlat(True)
        self.p22.setObjectName("p22")
        self.gridLayout_4.addWidget(self.p22, 7, 6, 3, 2)
        self.p13 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p13.sizePolicy().hasHeightForWidth())
        self.p13.setSizePolicy(sizePolicy)
        self.p13.setText("")
        self.p13.setIcon(icon2)
        self.p13.setIconSize(QtCore.QSize(40, 40))
        self.p13.setFlat(True)
        self.p13.setObjectName("p13")
        self.gridLayout_4.addWidget(self.p13, 7, 14, 3, 2)
        self.p5 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p5.sizePolicy().hasHeightForWidth())
        self.p5.setSizePolicy(sizePolicy)
        self.p5.setText("")
        self.p5.setIcon(icon2)
        self.p5.setIconSize(QtCore.QSize(40, 40))
        self.p5.setFlat(True)
        self.p5.setObjectName("p5")
        self.gridLayout_4.addWidget(self.p5, 8, 11, 4, 2)
        self.p15 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p15.sizePolicy().hasHeightForWidth())
        self.p15.setSizePolicy(sizePolicy)
        self.p15.setText("")
        self.p15.setIcon(icon2)
        self.p15.setIconSize(QtCore.QSize(40, 40))
        self.p15.setFlat(True)
        self.p15.setObjectName("p15")
        self.gridLayout_4.addWidget(self.p15, 8, 16, 3, 1)
        self.p30 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p30.sizePolicy().hasHeightForWidth())
        self.p30.setSizePolicy(sizePolicy)
        self.p30.setText("")
        self.p30.setIcon(icon2)
        self.p30.setIconSize(QtCore.QSize(40, 40))
        self.p30.setFlat(True)
        self.p30.setObjectName("p30")
        self.gridLayout_4.addWidget(self.p30, 9, 1, 4, 2)
        self.p27 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p27.sizePolicy().hasHeightForWidth())
        self.p27.setSizePolicy(sizePolicy)
        self.p27.setText("")
        self.p27.setIcon(icon2)
        self.p27.setIconSize(QtCore.QSize(40, 40))
        self.p27.setFlat(True)
        self.p27.setObjectName("p27")
        self.gridLayout_4.addWidget(self.p27, 10, 3, 4, 1)
        self.p32 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p32.sizePolicy().hasHeightForWidth())
        self.p32.setSizePolicy(sizePolicy)
        self.p32.setText("")
        self.p32.setIcon(icon2)
        self.p32.setIconSize(QtCore.QSize(40, 40))
        self.p32.setFlat(True)
        self.p32.setObjectName("p32")
        self.gridLayout_4.addWidget(self.p32, 10, 4, 4, 1)
        self.p9 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p9.sizePolicy().hasHeightForWidth())
        self.p9.setSizePolicy(sizePolicy)
        self.p9.setText("")
        self.p9.setIcon(icon2)
        self.p9.setIconSize(QtCore.QSize(40, 40))
        self.p9.setFlat(True)
        self.p9.setObjectName("p9")
        self.gridLayout_4.addWidget(self.p9, 10, 17, 4, 1)
        self.p7 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p7.sizePolicy().hasHeightForWidth())
        self.p7.setSizePolicy(sizePolicy)
        self.p7.setText("")
        self.p7.setIcon(icon2)
        self.p7.setIconSize(QtCore.QSize(40, 40))
        self.p7.setFlat(True)
        self.p7.setObjectName("p7")
        self.gridLayout_4.addWidget(self.p7, 11, 7, 3, 2)
        self.p14 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p14.sizePolicy().hasHeightForWidth())
        self.p14.setSizePolicy(sizePolicy)
        self.p14.setText("")
        self.p14.setIcon(icon2)
        self.p14.setIconSize(QtCore.QSize(40, 40))
        self.p14.setFlat(True)
        self.p14.setObjectName("p14")
        self.gridLayout_4.addWidget(self.p14, 12, 13, 2, 2)
        self.p8 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p8.sizePolicy().hasHeightForWidth())
        self.p8.setSizePolicy(sizePolicy)
        self.p8.setText("")
        self.p8.setIcon(icon2)
        self.p8.setIconSize(QtCore.QSize(40, 40))
        self.p8.setFlat(True)
        self.p8.setObjectName("p8")
        self.gridLayout_4.addWidget(self.p8, 12, 16, 2, 1)
        self.p25 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p25.sizePolicy().hasHeightForWidth())
        self.p25.setSizePolicy(sizePolicy)
        self.p25.setText("")
        self.p25.setIcon(icon2)
        self.p25.setIconSize(QtCore.QSize(40, 40))
        self.p25.setFlat(True)
        self.p25.setObjectName("p25")
        self.gridLayout_4.addWidget(self.p25, 13, 0, 1, 1)
        self.p19 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p19.sizePolicy().hasHeightForWidth())
        self.p19.setSizePolicy(sizePolicy)
        self.p19.setText("")
        self.p19.setIcon(icon2)
        self.p19.setIconSize(QtCore.QSize(40, 40))
        self.p19.setFlat(True)
        self.p19.setObjectName("p19")
        self.gridLayout_4.addWidget(self.p19, 13, 10, 1, 2)
        self.p28 = QtWidgets.QPushButton(self.frame_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.p28.sizePolicy().hasHeightForWidth())
        self.p28.setSizePolicy(sizePolicy)
        self.p28.setText('')
        self.p28.setIcon(icon2)
        self.p28.setIconSize(QtCore.QSize(40, 40))
        self.p28.setFlat(True)
        self.p28.setObjectName("p28")
        self.gridLayout_4.addWidget(self.p28, 4, 2, 1, 1)
        self.verticalLayout_14.addWidget(self.frame_2)
        self.gridLayout_5.addLayout(self.verticalLayout_14, 0, 0, 1, 1)
        
        self.horizontalLayout_22 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_22.setObjectName("horizontalLayout_22")
        self.pushButton_2 = QtWidgets.QPushButton(self.page_3)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.pushButton_2.sizePolicy().hasHeightForWidth())
        self.pushButton_2.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(10)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_2.setFont(font)
        self.pushButton_2.setStyleSheet("background-color: rgb(255, 88, 91);")
        self.pushButton_2.setObjectName("pushButton_2")
        
#         edited
        self.pushButton_2.clicked.connect(self.back2home)
        self.horizontalLayout_22.addWidget(self.pushButton_2)
        self.gridLayout_5.addLayout(self.horizontalLayout_22, 1, 0, 1, 1)
        
        self.stackedWidget.addWidget(self.page_3)
        self.page_2 = QtWidgets.QWidget()
        self.page_2.setObjectName("page_2")
        self.gridLayout_3 = QtWidgets.QGridLayout(self.page_2)
        self.gridLayout_3.setObjectName("gridLayout_3")
        self.verticalLayout_5 = QtWidgets.QVBoxLayout()
        self.verticalLayout_5.setObjectName("verticalLayout_5")
        spacerItem35 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_5.addItem(spacerItem35)
        self.horizontalLayout_13 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_13.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_13.setObjectName("horizontalLayout_13")
        spacerItem36 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_13.addItem(spacerItem36)
        self.TitleLabel = QtWidgets.QLabel(self.page_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.TitleLabel.sizePolicy().hasHeightForWidth())
        self.TitleLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Comic Sans MS")
        font.setPointSize(24)
        font.setBold(True)
        font.setWeight(75)
        self.TitleLabel.setFont(font)
        self.TitleLabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.TitleLabel.setAlignment(QtCore.Qt.AlignCenter)
        self.TitleLabel.setObjectName("TitleLabel")
        self.horizontalLayout_13.addWidget(self.TitleLabel)
        spacerItem37 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_13.addItem(spacerItem37)
        self.verticalLayout_5.addLayout(self.horizontalLayout_13)
        spacerItem38 = QtWidgets.QSpacerItem(20, 60, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_5.addItem(spacerItem38)
        self.horizontalLayout_14 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_14.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_14.setObjectName("horizontalLayout_14")
        spacerItem39 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_14.addItem(spacerItem39)
        self.ctwButton = QtWidgets.QPushButton(self.page_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctwButton.sizePolicy().hasHeightForWidth())
        self.ctwButton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Khmer UI")
        font.setPointSize(16)
        font.setBold(True)
        font.setWeight(75)
        self.ctwButton.setFont(font)
        self.ctwButton.setStyleSheet("border-image: url(ctwbuttonback.jpg);border-style: solid;border-color: black;border-width: 5px;border-radius: 10px;")
        self.ctwButton.setObjectName("ctwButton")
        
#         edited
        self.ctwButton.clicked.connect(self.optionalselect)
        
        self.horizontalLayout_14.addWidget(self.ctwButton)
        spacerItem40 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_14.addItem(spacerItem40)
        self.verticalLayout_5.addLayout(self.horizontalLayout_14)
        spacerItem41 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Fixed)
        self.verticalLayout_5.addItem(spacerItem41)
        self.horizontalLayout_15 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_15.setObjectName("horizontalLayout_15")
        spacerItem42 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_15.addItem(spacerItem42)
        self.ptpButton = QtWidgets.QPushButton(self.page_2)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ptpButton.sizePolicy().hasHeightForWidth())
        self.ptpButton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Khmer UI")
        font.setPointSize(16)
        font.setBold(True)
        font.setWeight(75)
        self.ptpButton.setFont(font)
        self.ptpButton.setStyleSheet("border-image: url(ctwbuttonback.jpg);border-style: solid;border-color: black;border-width: 5px;border-radius: 10px;")
        self.ptpButton.setObjectName("ptpButton")
        
#         edited
        self.ptpButton.clicked.connect(self.nav2stf)
    
        self.horizontalLayout_15.addWidget(self.ptpButton)
        spacerItem43 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_15.addItem(spacerItem43)
        self.verticalLayout_5.addLayout(self.horizontalLayout_15)
        spacerItem44 = QtWidgets.QSpacerItem(20, 40, QtWidgets.QSizePolicy.Minimum, QtWidgets.QSizePolicy.Expanding)
        self.verticalLayout_5.addItem(spacerItem44)
        self.gridLayout_3.addLayout(self.verticalLayout_5, 0, 0, 1, 1)
        self.stackedWidget.addWidget(self.page_2)
#         edited
        
        self.page_4 = QtWidgets.QWidget()
        self.page_4.setObjectName("page_4")
        self.gridLayout_6 = QtWidgets.QGridLayout(self.page_4)
        self.gridLayout_6.setObjectName("gridLayout_6")
        self.verticalLayout_16 = QtWidgets.QVBoxLayout()
        self.verticalLayout_16.setObjectName("verticalLayout_16")
        self.horizontalLayout_23 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_23.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_23.setObjectName("horizontalLayout_23")
        self.ctw2back = QtWidgets.QPushButton(self.page_4)
        self.ctw2back.setText("")
        icon4 = QtGui.QIcon()
        icon4.addPixmap(QtGui.QPixmap("icons/arrows.gif"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.ctw2back.setIcon(icon4)
        self.ctw2back.setIconSize(QtCore.QSize(30, 30))
        self.ctw2back.setFlat(True)
        self.ctw2back.setObjectName("ctw2back")
        self.ctw2back.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.ctw2back.setToolTip("Back")
        self.ctw2back.clicked.connect(self.back2home)
        self.horizontalLayout_23.addWidget(self.ctw2back)
        spacerItem47 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_23.addItem(spacerItem47)
        self.ctw2titlelabel = QtWidgets.QLabel(self.page_4)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2titlelabel.sizePolicy().hasHeightForWidth())
        self.ctw2titlelabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(16)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2titlelabel.setFont(font)
        self.ctw2titlelabel.setObjectName("ctw2titlelabel")
        self.ctw2titlelabel.setStyleSheet("color: rgb(255, 255, 255);")
        self.horizontalLayout_23.addWidget(self.ctw2titlelabel)
        spacerItem48 = QtWidgets.QSpacerItem(40, 20, QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_23.addItem(spacerItem48)
        self.verticalLayout_16.addLayout(self.horizontalLayout_23)
        self.scrollArea = QtWidgets.QScrollArea(self.page_4)
        self.scrollArea.setWidgetResizable(True)
        self.scrollArea.setStyleSheet(".QWidget{border-image: url(lightbackground.jpg);}")
        self.scrollArea.setObjectName("scrollArea")
        self.scrollAreaWidgetContents = QtWidgets.QWidget()
        self.scrollAreaWidgetContents.setGeometry(QtCore.QRect(0, 0, 798, 611))
        self.scrollAreaWidgetContents.setObjectName("scrollAreaWidgetContents")
#         self.scrollAreaWidgetContents.setStyleSheet(".QWidget{border-image: url(scrollback.jpg);}")
        self.gridLayout_7 = QtWidgets.QGridLayout(self.scrollAreaWidgetContents)
        self.gridLayout_7.setObjectName("gridLayout_7")
        self.verticalLayout_27 = QtWidgets.QVBoxLayout()
        self.verticalLayout_27.setObjectName("verticalLayout_27")
        self.horizontalLayout_27 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_27.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_27.setObjectName("horizontalLayout_27")
        self.ctw2abcframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2abcframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2abcframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2abcframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2abcframe.setObjectName("ctw2abcframe")
        self.gridLayout_13 = QtWidgets.QGridLayout(self.ctw2abcframe)
        self.gridLayout_13.setObjectName("gridLayout_13")
        self.verticalLayout_23 = QtWidgets.QVBoxLayout()
        self.verticalLayout_23.setObjectName("verticalLayout_23")
        self.ctw2abclabel = QtWidgets.QLabel(self.ctw2abcframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2abclabel.setFont(font)
        self.ctw2abclabel.setObjectName("ctw2abclabel")
        self.verticalLayout_23.addWidget(self.ctw2abclabel)
        self.ctw2abclabel1 = QtWidgets.QLabel(self.ctw2abcframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2abclabel1.sizePolicy().hasHeightForWidth())
        self.ctw2abclabel1.setSizePolicy(sizePolicy)
        self.ctw2abclabel1.setObjectName("ctw2abclabel1")
        self.verticalLayout_23.addWidget(self.ctw2abclabel1)
        self.ctw2abcprogressbar = QtWidgets.QProgressBar(self.ctw2abcframe)
        self.ctw2abcprogressbar.setProperty("value", 24)
        self.ctw2abcprogressbar.setObjectName("ctw2abcprogressbar")
        self.verticalLayout_23.addWidget(self.ctw2abcprogressbar)
        self.ctw2abcbutton = QtWidgets.QPushButton(self.ctw2abcframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2abcbutton.sizePolicy().hasHeightForWidth())
        self.ctw2abcbutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2abcbutton.setFont(font)
        self.ctw2abcbutton.setStyleSheet("background-color: rgb(255, 255, 141);")
        self.ctw2abcbutton.setObjectName("ctw2abcbutton")
        self.verticalLayout_23.addWidget(self.ctw2abcbutton)
        self.gridLayout_13.addLayout(self.verticalLayout_23, 0, 0, 1, 1)
        self.horizontalLayout_27.addWidget(self.ctw2abcframe)
        spacerItem49 = QtWidgets.QSpacerItem(30, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_27.addItem(spacerItem49)
        self.ctw2defframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2defframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2defframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2defframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2defframe.setObjectName("ctw2defframe")
        self.gridLayout_14 = QtWidgets.QGridLayout(self.ctw2defframe)
        self.gridLayout_14.setObjectName("gridLayout_14")
        self.verticalLayout_24 = QtWidgets.QVBoxLayout()
        self.verticalLayout_24.setObjectName("verticalLayout_24")
        self.ctw2deflabel = QtWidgets.QLabel(self.ctw2defframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2deflabel.setFont(font)
        self.ctw2deflabel.setObjectName("ctw2deflabel")
        self.verticalLayout_24.addWidget(self.ctw2deflabel)
        self.ctw2deflabel1 = QtWidgets.QLabel(self.ctw2defframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2deflabel1.sizePolicy().hasHeightForWidth())
        self.ctw2deflabel1.setSizePolicy(sizePolicy)
        self.ctw2deflabel1.setObjectName("ctw2deflabel1")
        self.verticalLayout_24.addWidget(self.ctw2deflabel1)
        self.ctw2defprogressbar = QtWidgets.QProgressBar(self.ctw2defframe)
        self.ctw2defprogressbar.setProperty("value", 24)
        self.ctw2defprogressbar.setObjectName("ctw2defprogressbar")
        self.verticalLayout_24.addWidget(self.ctw2defprogressbar)
        self.ctw2defbutton = QtWidgets.QPushButton(self.ctw2defframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2defbutton.sizePolicy().hasHeightForWidth())
        self.ctw2defbutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2defbutton.setFont(font)
        self.ctw2defbutton.setStyleSheet("background-color: rgb(218, 205, 181);")
        self.ctw2defbutton.setObjectName("ctw2defbutton")
        self.verticalLayout_24.addWidget(self.ctw2defbutton)
        self.gridLayout_14.addLayout(self.verticalLayout_24, 0, 0, 1, 1)
        self.horizontalLayout_27.addWidget(self.ctw2defframe)
        self.verticalLayout_27.addLayout(self.horizontalLayout_27)
        self.horizontalLayout_25 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_25.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_25.setObjectName("horizontalLayout_25")
        self.ctw2ghiframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2ghiframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2ghiframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2ghiframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2ghiframe.setObjectName("ctw2ghiframe")
        self.gridLayout_9 = QtWidgets.QGridLayout(self.ctw2ghiframe)
        self.gridLayout_9.setObjectName("gridLayout_9")
        self.verticalLayout_19 = QtWidgets.QVBoxLayout()
        self.verticalLayout_19.setObjectName("verticalLayout_19")
        self.ctw2ghilabel = QtWidgets.QLabel(self.ctw2ghiframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2ghilabel.setFont(font)
        self.ctw2ghilabel.setObjectName("ctw2ghilabel")
        self.verticalLayout_19.addWidget(self.ctw2ghilabel)
        self.ctw2ghilabel1 = QtWidgets.QLabel(self.ctw2ghiframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2ghilabel1.sizePolicy().hasHeightForWidth())
        self.ctw2ghilabel1.setSizePolicy(sizePolicy)
        self.ctw2ghilabel1.setObjectName("ctw2ghilabel1")
        self.verticalLayout_19.addWidget(self.ctw2ghilabel1)
        self.ctw2ghiprogressbar = QtWidgets.QProgressBar(self.ctw2ghiframe)
        self.ctw2ghiprogressbar.setProperty("value", 24)
        self.ctw2ghiprogressbar.setObjectName("ctw2ghiprogressbar")
        self.verticalLayout_19.addWidget(self.ctw2ghiprogressbar)
        self.ctw2ghibutton = QtWidgets.QPushButton(self.ctw2ghiframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2ghibutton.sizePolicy().hasHeightForWidth())
        self.ctw2ghibutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2ghibutton.setFont(font)
        self.ctw2ghibutton.setStyleSheet("background-color: rgb(218, 205, 181);")
        self.ctw2ghibutton.setObjectName("ctw2ghibutton")
        self.verticalLayout_19.addWidget(self.ctw2ghibutton)
        self.gridLayout_9.addLayout(self.verticalLayout_19, 0, 0, 1, 1)
        self.horizontalLayout_25.addWidget(self.ctw2ghiframe)
        spacerItem50 = QtWidgets.QSpacerItem(30, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_25.addItem(spacerItem50)
        self.ctw2jklframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2jklframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2jklframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2jklframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2jklframe.setObjectName("ctw2jklframe")
        self.gridLayout_10 = QtWidgets.QGridLayout(self.ctw2jklframe)
        self.gridLayout_10.setObjectName("gridLayout_10")
        self.verticalLayout_20 = QtWidgets.QVBoxLayout()
        self.verticalLayout_20.setObjectName("verticalLayout_20")
        self.ctw2jkllabel = QtWidgets.QLabel(self.ctw2jklframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2jkllabel.setFont(font)
        self.ctw2jkllabel.setObjectName("ctw2jkllabel")
        self.verticalLayout_20.addWidget(self.ctw2jkllabel)
        self.ctw2jkllabel1 = QtWidgets.QLabel(self.ctw2jklframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2jkllabel1.sizePolicy().hasHeightForWidth())
        self.ctw2jkllabel1.setSizePolicy(sizePolicy)
        self.ctw2jkllabel1.setObjectName("ctw2jkllabel1")
        self.verticalLayout_20.addWidget(self.ctw2jkllabel1)
        self.ctw2jklprogressbar = QtWidgets.QProgressBar(self.ctw2jklframe)
        self.ctw2jklprogressbar.setProperty("value", 24)
        self.ctw2jklprogressbar.setObjectName("ctw2jklprogressbar")
        self.verticalLayout_20.addWidget(self.ctw2jklprogressbar)
        self.ctw2jklbutton = QtWidgets.QPushButton(self.ctw2jklframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2jklbutton.sizePolicy().hasHeightForWidth())
        self.ctw2jklbutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2jklbutton.setFont(font)
        self.ctw2jklbutton.setStyleSheet("background-color: rgb(218, 205, 181);\n"
"")
        self.ctw2jklbutton.setObjectName("ctw2jklbutton")
        self.verticalLayout_20.addWidget(self.ctw2jklbutton)
        self.gridLayout_10.addLayout(self.verticalLayout_20, 0, 0, 1, 1)
        self.horizontalLayout_25.addWidget(self.ctw2jklframe)
        self.verticalLayout_27.addLayout(self.horizontalLayout_25)
        self.horizontalLayout_26 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_26.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_26.setObjectName("horizontalLayout_26")
        self.ctw2mnoframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2mnoframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2mnoframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2mnoframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2mnoframe.setObjectName("ctw2mnoframe")
        self.gridLayout_11 = QtWidgets.QGridLayout(self.ctw2mnoframe)
        self.gridLayout_11.setObjectName("gridLayout_11")
        self.verticalLayout_21 = QtWidgets.QVBoxLayout()
        self.verticalLayout_21.setObjectName("verticalLayout_21")
        self.ctw2mnolabel = QtWidgets.QLabel(self.ctw2mnoframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2mnolabel.setFont(font)
        self.ctw2mnolabel.setObjectName("ctw2mnolabel")
        self.verticalLayout_21.addWidget(self.ctw2mnolabel)
        self.ctw2mnolabel1 = QtWidgets.QLabel(self.ctw2mnoframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2mnolabel1.sizePolicy().hasHeightForWidth())
        self.ctw2mnolabel1.setSizePolicy(sizePolicy)
        self.ctw2mnolabel1.setObjectName("ctw2mnolabel1")
        self.verticalLayout_21.addWidget(self.ctw2mnolabel1)
        self.ctw2mnoprogressbar = QtWidgets.QProgressBar(self.ctw2mnoframe)
        self.ctw2mnoprogressbar.setProperty("value", 24)
        self.ctw2mnoprogressbar.setObjectName("ctw2mnoprogressbar")
        self.verticalLayout_21.addWidget(self.ctw2mnoprogressbar)
        self.ctw2mnobutton = QtWidgets.QPushButton(self.ctw2mnoframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2mnobutton.sizePolicy().hasHeightForWidth())
        self.ctw2mnobutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2mnobutton.setFont(font)
        self.ctw2mnobutton.setStyleSheet("background-color: rgb(218, 205, 181);")
        self.ctw2mnobutton.setObjectName("ctw2mnobutton")
        self.verticalLayout_21.addWidget(self.ctw2mnobutton)
        self.gridLayout_11.addLayout(self.verticalLayout_21, 0, 0, 1, 1)
        self.horizontalLayout_26.addWidget(self.ctw2mnoframe)
        spacerItem51 = QtWidgets.QSpacerItem(30, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_26.addItem(spacerItem51)
        self.ctw2pqrframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2pqrframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2pqrframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2pqrframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2pqrframe.setObjectName("ctw2pqrframe")
        self.gridLayout_12 = QtWidgets.QGridLayout(self.ctw2pqrframe)
        self.gridLayout_12.setObjectName("gridLayout_12")
        self.verticalLayout_22 = QtWidgets.QVBoxLayout()
        self.verticalLayout_22.setObjectName("verticalLayout_22")
        self.ctw2pqrlabel = QtWidgets.QLabel(self.ctw2pqrframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2pqrlabel.setFont(font)
        self.ctw2pqrlabel.setObjectName("ctw2pqrlabel")
        self.verticalLayout_22.addWidget(self.ctw2pqrlabel)
        self.ctw2pqrlabel_2 = QtWidgets.QLabel(self.ctw2pqrframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2pqrlabel_2.sizePolicy().hasHeightForWidth())
        self.ctw2pqrlabel_2.setSizePolicy(sizePolicy)
        self.ctw2pqrlabel_2.setObjectName("ctw2pqrlabel_2")
        self.verticalLayout_22.addWidget(self.ctw2pqrlabel_2)
        self.ctw2pqrprogressbar = QtWidgets.QProgressBar(self.ctw2pqrframe)
        self.ctw2pqrprogressbar.setProperty("value", 24)
        self.ctw2pqrprogressbar.setObjectName("ctw2pqrprogressbar")
        self.verticalLayout_22.addWidget(self.ctw2pqrprogressbar)
        self.ctw2pqrbutton = QtWidgets.QPushButton(self.ctw2pqrframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2pqrbutton.sizePolicy().hasHeightForWidth())
        self.ctw2pqrbutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2pqrbutton.setFont(font)
        self.ctw2pqrbutton.setStyleSheet("background-color: rgb(218, 205, 181);            ")
        self.ctw2pqrbutton.setObjectName("ctw2pqrbutton")
        self.verticalLayout_22.addWidget(self.ctw2pqrbutton)
        self.gridLayout_12.addLayout(self.verticalLayout_22, 0, 0, 1, 1)
        self.horizontalLayout_26.addWidget(self.ctw2pqrframe)
        self.verticalLayout_27.addLayout(self.horizontalLayout_26)
        self.horizontalLayout_28 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_28.setSizeConstraint(QtWidgets.QLayout.SetFixedSize)
        self.horizontalLayout_28.setObjectName("horizontalLayout_28")
        self.ctw2stuvframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2stuvframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2stuvframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2stuvframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2stuvframe.setObjectName("ctw2stuvframe")
        self.gridLayout_15 = QtWidgets.QGridLayout(self.ctw2stuvframe)
        self.gridLayout_15.setObjectName("gridLayout_15")
        self.verticalLayout_25 = QtWidgets.QVBoxLayout()
        self.verticalLayout_25.setObjectName("verticalLayout_25")
        self.ctw2stuvlabel = QtWidgets.QLabel(self.ctw2stuvframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2stuvlabel.setFont(font)
        self.ctw2stuvlabel.setObjectName("ctw2stuvlabel")
        self.verticalLayout_25.addWidget(self.ctw2stuvlabel)
        self.ctw2stuvlabel1 = QtWidgets.QLabel(self.ctw2stuvframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2stuvlabel1.sizePolicy().hasHeightForWidth())
        self.ctw2stuvlabel1.setSizePolicy(sizePolicy)
        self.ctw2stuvlabel1.setObjectName("ctw2stuvlabel1")
        self.verticalLayout_25.addWidget(self.ctw2stuvlabel1)
        self.ctw2stuvprogressbar = QtWidgets.QProgressBar(self.ctw2stuvframe)
        self.ctw2stuvprogressbar.setProperty("value", 24)
        self.ctw2stuvprogressbar.setObjectName("ctw2stuvprogressbar")
        self.verticalLayout_25.addWidget(self.ctw2stuvprogressbar)
        self.ctw2stuvbutton = QtWidgets.QPushButton(self.ctw2stuvframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2stuvbutton.sizePolicy().hasHeightForWidth())
        self.ctw2stuvbutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2stuvbutton.setFont(font)
        self.ctw2stuvbutton.setStyleSheet("background-color: rgb(218, 205, 181);")
        self.ctw2stuvbutton.setObjectName("ctw2stuvbutton")
        self.verticalLayout_25.addWidget(self.ctw2stuvbutton)
        self.gridLayout_15.addLayout(self.verticalLayout_25, 0, 0, 1, 1)
        self.horizontalLayout_28.addWidget(self.ctw2stuvframe)
        spacerItem52 = QtWidgets.QSpacerItem(30, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_28.addItem(spacerItem52)
        self.ctw2wxyzframe = QtWidgets.QFrame(self.scrollAreaWidgetContents)
        self.ctw2wxyzframe.setStyleSheet("background-color: rgb(220, 220, 220);")
        self.ctw2wxyzframe.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.ctw2wxyzframe.setFrameShadow(QtWidgets.QFrame.Raised)
        self.ctw2wxyzframe.setObjectName("ctw2wxyzframe")
        self.gridLayout_16 = QtWidgets.QGridLayout(self.ctw2wxyzframe)
        self.gridLayout_16.setObjectName("gridLayout_16")
        self.verticalLayout_26 = QtWidgets.QVBoxLayout()
        self.verticalLayout_26.setObjectName("verticalLayout_26")
        self.ctw2wxyzlabel = QtWidgets.QLabel(self.ctw2wxyzframe)
        font = QtGui.QFont()
        font.setPointSize(13)
        font.setBold(True)
        font.setWeight(75)
        self.ctw2wxyzlabel.setFont(font)
        self.ctw2wxyzlabel.setObjectName("ctw2wxyzlabel")
        self.verticalLayout_26.addWidget(self.ctw2wxyzlabel)
        self.ctw2wxyzlabel_2 = QtWidgets.QLabel(self.ctw2wxyzframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2wxyzlabel_2.sizePolicy().hasHeightForWidth())
        self.ctw2wxyzlabel_2.setSizePolicy(sizePolicy)
        self.ctw2wxyzlabel_2.setObjectName("ctw2wxyzlabel_2")
        self.verticalLayout_26.addWidget(self.ctw2wxyzlabel_2)
        self.ctw2wxyzprogressbar = QtWidgets.QProgressBar(self.ctw2wxyzframe)
        self.ctw2wxyzprogressbar.setProperty("value", 24)
        self.ctw2wxyzprogressbar.setObjectName("ctw2wxyzprogressbar")
        self.verticalLayout_26.addWidget(self.ctw2wxyzprogressbar)
        self.ctw2wxyzbutton = QtWidgets.QPushButton(self.ctw2wxyzframe)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.ctw2wxyzbutton.sizePolicy().hasHeightForWidth())
        self.ctw2wxyzbutton.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Monospac821 BT")
        font.setPointSize(15)
        font.setBold(False)
        font.setWeight(50)
        self.ctw2wxyzbutton.setFont(font)
        self.ctw2wxyzbutton.setStyleSheet("background-color: rgb(218, 205, 181);")
        self.ctw2wxyzbutton.setObjectName("ctw2wxyzbutton")
        self.verticalLayout_26.addWidget(self.ctw2wxyzbutton)
        self.gridLayout_16.addLayout(self.verticalLayout_26, 0, 0, 1, 1)
        self.horizontalLayout_28.addWidget(self.ctw2wxyzframe)
        self.verticalLayout_27.addLayout(self.horizontalLayout_28)
        self.gridLayout_7.addLayout(self.verticalLayout_27, 0, 0, 1, 1)
        self.scrollArea.setWidget(self.scrollAreaWidgetContents)
        self.verticalLayout_16.addWidget(self.scrollArea)
        self.gridLayout_6.addLayout(self.verticalLayout_16, 0, 0, 1, 1)
        self.stackedWidget.addWidget(self.page_4)
# edited
        
        
        
        self.verticalLayout_9.addWidget(self.stackedWidget)
        self.horizontalLayout_10 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_10.setSpacing(0)
        self.horizontalLayout_10.setObjectName("horizontalLayout_10")
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setStyleSheet("background-color: qlineargradient(spread:repeat, x1:0.11, y1:0.1, x2:0.908249, y2:0.106, stop:0.322034 rgba(255, 202, 137, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.horizontalLayout_11 = QtWidgets.QHBoxLayout(self.frame)
        self.horizontalLayout_11.setObjectName("horizontalLayout_11")
        self.quoteLabel = QtWidgets.QLabel(self.frame)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.quoteLabel.sizePolicy().hasHeightForWidth())
        self.quoteLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.quoteLabel.setFont(font)
        self.quoteLabel.setObjectName("quoteLabel")
        self.horizontalLayout_11.addWidget(self.quoteLabel)
        spacerItem45 = QtWidgets.QSpacerItem(200, 20, QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Minimum)
        self.horizontalLayout_11.addItem(spacerItem45)
        self.appbyLabel = QtWidgets.QLabel(self.frame)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Fixed)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.appbyLabel.sizePolicy().hasHeightForWidth())
        self.appbyLabel.setSizePolicy(sizePolicy)
        font = QtGui.QFont()
        font.setPointSize(9)
        
        self.appbyLabel.setFont(font)
        self.appbyLabel.setObjectName("appbyLabel")
        self.horizontalLayout_11.addWidget(self.appbyLabel)
        self.horizontalLayout_10.addWidget(self.frame)
        self.verticalLayout_9.addLayout(self.horizontalLayout_10)
        self.gridLayout_2.addLayout(self.verticalLayout_9, 0, 0, 1, 1)
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 822, 21))
        self.menubar.setObjectName("menubar")
        self.menuFile = QtWidgets.QMenu(self.menubar)
        self.menuFile.setObjectName("menuFile")
        
        self.menuAbout = QtWidgets.QMenu(self.menubar)
        self.menuAbout.setObjectName("menuAbout")
        
        MainWindow.setMenuBar(self.menubar)
        self.actionSave = QtWidgets.QAction(MainWindow)
        self.actionSave.setObjectName("actionSave")
        icon6 = QtGui.QIcon()
        icon6.addPixmap(QtGui.QPixmap("info.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.actionSave.setIcon(icon6)
        
        self.actionSave.triggered.connect(self.saveProgress)
#         self.actionSave.setEnabled(False)
        self.actionInfo = QtWidgets.QAction(MainWindow)
        icon5 = QtGui.QIcon()
        icon5.addPixmap(QtGui.QPixmap("icons/save.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.actionInfo.setIcon(icon5)
        
        self.actionInfo.setObjectName("actionInfo")
        self.actionInfo.triggered.connect(self.abouttheapp)
        
        
        self.menuFile.addAction(self.actionSave)
        self.menuAbout.addAction(self.actionInfo)
        
        self.menubar.addAction(self.menuFile.menuAction())
        self.menubar.addAction(self.menuAbout.menuAction())
        
#         edited
        self.stfbuttonlist=[self.p1,self.p2,self.p3,self.p4,self.p5,self.p6,self.p7,self.p8,self.p9,self.p10,self.p11,self.p12,
                           self.p13,self.p14,self.p15,self.p16,self.p17,self.p18,self.p19,self.p20,self.p21,
                           self.p22,self.p23,self.p24,self.p25,self.p26,self.p27,self.p28,self.p29,self.p30,self.p31,self.p32]
        for i in range(len(self.stfbuttonlist)):
            self.stfbuttonlist[i].setStyleSheet("color: rgb(255, 255, 255);fra")
        for i in range(len(self.stfbuttonlist)):
            self.stfbuttonlist[i].clicked.connect(self.alphaclicked)
#         edited
#         df=pd.read_csv('3000_common_words.csv',header=None,delimiter=',')
#         self.words_arr=list(df[0])
#         self.stfindicator.setHidden(True)
#         edited
        df1=pd.read_csv('fauna list.csv',header=None,delimiter=',')
        self.fauna_list=list(df1.iloc[:,0])
        print('hello there')
        self.ctwoptionalBut={'abc':self.ctw2abcbutton,'def':self.ctw2defbutton,'ghi':self.ctw2ghibutton,'jkl':self.ctw2jklbutton,'mno':self.ctw2mnobutton,'pqr':self.ctw2pqrbutton,'stuv':self.ctw2stuvbutton,'wxyz':self.ctw2wxyzbutton}
        
        self.progressBarDict={'abc':self.ctw2abcprogressbar,'def':self.ctw2defprogressbar,'ghi':self.ctw2ghiprogressbar,'jkl':self.ctw2jklprogressbar,'mno':self.ctw2mnoprogressbar,'pqr':self.ctw2pqrprogressbar,'stuv':self.ctw2stuvprogressbar,'wxyz':self.ctw2wxyzprogressbar}
#         for i in self.progressBarDict:
#             try:
#                 self.dtf=pd.read_csv('ctw/save/'+i+'/'+i+'listcorrect.csv',header=None,delimiter=',')
#                 dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
#                 self.size=len(dtsizer[0])
#                 self.progressBarDict[i].setValue(int((len(self.dtf[0])/self.size)*100))
#                 print(i)
                
#             except:
                
#                 self.progressBarDict[str(i)].setValue(int(0))
        self.stfLineedit.setReadOnly(True)
        self.clicked_order_list=[]
        magooshbuttonlist=[self.ctw2abcbutton,self.ctw2defbutton,self.ctw2ghibutton,self.ctw2jklbutton,self.ctw2mnobutton,self.ctw2pqrbutton,self.ctw2stuvbutton,self.ctw2wxyzbutton]
        for i in magooshbuttonlist:
            i.clicked.connect(self.navigate2ctw)
        print("ci"+str(self.stackedWidget.currentIndex()))
#         if(self.stackedWidget.currentIndex()==0):
#             self.actionSave.setEnabled(True)
        self.retranslateUi(MainWindow)
        self.stackedWidget.setCurrentIndex(2)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        
    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.b2homeButton.setText(_translate("MainWindow", "BACK TO HOMEPAGE"))
        self.qnumLabel.setText(_translate("MainWindow", "100"))
        self.ctwtitleLabel.setText(_translate("MainWindow", "Catch T Woord"))
        self.scoreLabel.setText(_translate("MainWindow", "SCORE: 100"))
        self.ctwcheckButton.setText(_translate("MainWindow", "CHECK"))
        self.ctwnextButton.setText(_translate("MainWindow", "NEXT"))
        self.resultLabel.setText(_translate("MainWindow", "No, you are wrong...vikrama raghuraman is the right answer"))
        self.stftopicLabel.setText(_translate("MainWindow", "Spell T Fauna"))
        self.stfqnumLabel.setText(_translate("MainWindow", "1"))
        self.stfscoreLabel.setText(_translate("MainWindow", "SCORE: 0"))
        self.label.setText(_translate("MainWindow", "Vikrama raghuman is the answer"))
        self.ptfcheckButton.setText(_translate("MainWindow", "CHECK"))
        self.stfnextButton.setText(_translate("MainWindow", "NEXT"))
        self.TitleLabel.setText(_translate("MainWindow", "Flair 4 words"))
        self.ctwButton.setText(_translate("MainWindow", "Catch T Woord"))
        self.ptpButton.setText(_translate("MainWindow", "Spell T Fauna"))
        self.ctw2titlelabel.setText(_translate("MainWindow", "Catch T Woord"))
        self.ctw2abclabel.setText(_translate("MainWindow", "Common Words ABC"))
        self.ctw2abclabel1.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2abcbutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.ctw2deflabel.setText(_translate("MainWindow", "Common Words DEF"))
        self.ctw2deflabel1.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2defbutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.ctw2ghilabel.setText(_translate("MainWindow", "Common Words GHI"))
        self.ctw2ghilabel1.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2ghibutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.ctw2jkllabel.setText(_translate("MainWindow", "Common Words JKL"))
        self.ctw2jkllabel1.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2jklbutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.ctw2mnolabel.setText(_translate("MainWindow", "Common Words MNO"))
        self.ctw2mnolabel1.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2mnobutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.ctw2pqrlabel.setText(_translate("MainWindow", "Common Words PQR"))
        self.ctw2pqrlabel_2.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2pqrbutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.ctw2stuvlabel.setText(_translate("MainWindow", "Common Words STUV"))
        self.ctw2stuvlabel1.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2stuvbutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.ctw2wxyzlabel.setText(_translate("MainWindow", "Common Words WXYZ"))
        self.ctw2wxyzlabel_2.setText(_translate("MainWindow", " 0 of 50 words completed"))
        self.ctw2wxyzbutton.setText(_translate("MainWindow", "Practice this Deck >"))
        self.pushButton_2.setText(_translate("MainWindow", "BACK TO HOMEPAGE"))
        self.quoteLabel.setText(_translate("MainWindow", "Once you stop leanring, you start dying"))
        self.appbyLabel.setText(_translate("MainWindow", "APP Designed By: Vikrama Rgahuraman "))
        self.menuAbout.setTitle(_translate("MainWindow", "About"))
        self.menuFile.setTitle(_translate("MainWindow", "File"))
        self.actionInfo.setText(_translate("MainWindow", "Info"))
        self.actionSave.setText(_translate("MainWindow", "Save"))
    def play(self):
        engine = pyttsx3.init()
        engine.setProperty('rate', 100)
        engine.setProperty('volume', 1)
        engine.say(self.present)
        engine.runAndWait() 
    def check(self):
        self.indicatorLabel.setHidden(False)
        if(self.answerLineedit.text()==self.present):
            self.resultLabel.setText('Yes, you got that right...')
            self.score+=1
            self.scoreLabel.setText('SCORE: '+str(self.score))
            self.gif =QMovie('thumbsup_mod.gif')
            self.indicatorLabel.setMovie(self.gif)
            self.gif.start()
            try:
                dfnum1=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv',header=None)
                if(int(self.number2benoted) in dfnum1.values):
                    dfwrongdel=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv',header=None,delimiter=',')
                    dfwrongdel=dfwrongdel.iloc[1:len(dfwrongdel)]
                    dfwrongdel.to_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv', index=False,header=None)
            except:
                pass
            try:
                dfnum=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listcorrect.csv',header=None)
                if(int(self.number2benoted) not in dfnum.values):
                    with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listcorrect.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str(self.number2benoted)])
            except:
                with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listcorrect.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str(self.number2benoted)])
        else:
            self.resultLabel.setText('No, you are wrong... '+str(self.present)+' is the right answer')
            self.gif =QMovie('thumbsdown_mod.gif')
            self.indicatorLabel.setMovie(self.gif)
            self.gif.start()
            try:
                dfnum1=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv',header=None)
                if(int(self.incorrectFirstNum) not in dfnum1.values):
                    with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str(self.number2benoted)])
            except:
                with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str(self.number2benoted)])
        self.ctwcheckButton.setEnabled(False)
    def starter(self):
        if(self.impindicator=='regular'):
            self.number2benoted=int(self.ctwrandnum[self.number2cont])
            print('entered starter if')
            if(self.number2cont<len(self.words_arr)-1):
                self.qnum+=1
                self.qnumLabel.setText(str(self.qnum))
                self.resultLabel.setText('')
                self.indicatorLabel.setHidden(True)
                self.ctwcheckButton.setEnabled(True)
                self.present=self.words_arr[int(self.ctwrandnum[self.number2cont])]
                self.answerLineedit.setText('')
            else:
                self.qnum+=1
                self.qnumLabel.setText(str(self.qnum))
                self.resultLabel.setText('')
                self.indicatorLabel.setHidden(True)
                self.ctwcheckButton.setEnabled(True)
                self.present=self.words_arr[int(self.ctwrandnum[self.number2cont])]
                self.answerLineedit.setText('')
                f = open('ctw/save/'+str(self.chosen)+'/'+'indicator.csv', 'w')
                f.truncate()
                f.close()
                with open('ctw/save/'+str(self.chosen)+'/'+'indicator.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str('incorrect')])
                self.impindicator='incorrect'
        elif(self.impindicator=='incorrect'):
            dfincorrect=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv',header=None,delimiter=',')
            self.incorrectlist=list(dfincorrect[0])
            self.number2benoted=int(self.incorrectlist[0])
            try:
                self.qnum+=1
                self.qnumLabel.setText(str(self.qnum))
                self.resultLabel.setText('')
                self.indicatorLabel.setHidden(True)
                self.ctwcheckButton.setEnabled(True)
                self.present=self.words_arr[int(self.incorrectlist[0])]
                self.answerLineedit.setText('')
            except:
                pass  
    def ctwnext(self):
        with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv', 'r') as f:
            checker = csv.reader(f)
            checker=list(checker)
            if(len(checker)==0):
                self.empty=True
            else:
                self.empty=False
        if(self.ctwcheckButton.isEnabled()==True):
            try:
                dfnum1=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv',header=None)
                if(int(self.ctwrandnum[self.number2cont]) not in dfnum1.values):
                    with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str(self.ctwrandnum[self.number2cont])])
            except:
                with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str(self.ctwrandnum[self.number2cont])])
        if(self.impindicator=='regular'):
            self.number2cont+=1
            self.number2benoted=int(self.ctwrandnum[self.number2cont])
            print(self.number2cont)
            if(self.number2cont<len(self.words_arr)-1):
                self.qnum+=1
                self.qnumLabel.setText(str(self.qnum))
                self.resultLabel.setText('')
                self.indicatorLabel.setHidden(True)
                self.ctwcheckButton.setEnabled(True)
                self.present=self.words_arr[int(self.ctwrandnum[self.number2cont])]
                self.answerLineedit.setText('')
#                 self.number2cont+=1
            else:
                self.qnum+=1
                self.qnumLabel.setText(str(self.qnum))
                self.resultLabel.setText('')
                self.indicatorLabel.setHidden(True)
                self.ctwcheckButton.setEnabled(True)
                self.present=self.words_arr[int(self.ctwrandnum[self.number2cont])]
                self.answerLineedit.setText('')
                self.number2cont+=1
                f = open('ctw/save/'+str(self.chosen)+'/'+'indicator.csv', 'w')
                f.truncate()
                f.close()
                with open('ctw/save/'+str(self.chosen)+'/'+'indicator.csv', 'a') as f:
                        writer = csv.writer(f)
                        writer.writerow([str('incorrect')])
                self.impindicator='incorrect'
                
        elif(self.impindicator=='incorrect'):
            print('incorrect')
            if(self.empty==False):
                dfincorrect=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listwrong.csv',header=None,delimiter=',')
                self.incorrectlist=list(dfincorrect[0])
                self.number2benoted=int(self.incorrectlist[0])
                try:
                    self.qnum+=1
                    self.qnumLabel.setText(str(self.qnum))
                    self.resultLabel.setText('')
                    self.indicatorLabel.setHidden(True)
                    self.ctwcheckButton.setEnabled(True)
                    self.present=self.words_arr[int(self.incorrectlist[0])]
                    self.incorrectFirstNum=int(self.incorrectlist[0])
                    self.answerLineedit.setText('')
                except:
                    pass  
            else:
                obj=QtWidgets.QMainWindow()
                message=QMessageBox.information(obj, "Completed","You are all caught up")
                if(message==QMessageBox.Ok):
                    self.stackedWidget.setCurrentIndex(3)
                    self.ctwoptionalBut[self.chosen].setText('Replay again')
                    for i in self.progressBarDict:
                        try:
                            self.dtf=pd.read_csv('ctw/save/'+i+'/'+i+'listcorrect.csv',header=None,delimiter=',')
                            dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
                            self.size=len(dtsizer[0])
                            self.progressBarDict[i].setValue(int((len(self.dtf[0])/self.size)*100))
                            if(int((len(self.dtf[0])/self.size)*100)==100):
                                self.ctwoptionalBut[i].setText('Replay again')
                                print('yes I am there')
                            else:
                                self.ctwoptionalBut[i].setText('Practice this Deck >')
                        except:
                            self.progressBarDict[str(i)].setValue(int(0))
        print(self.present)
    def ctwback2home(self):
        if(self.impindicator=='regular'):
            self.progressBarDict={'abc':self.ctw2abcprogressbar,'def':self.ctw2defprogressbar,'ghi':self.ctw2ghiprogressbar,'jkl':self.ctw2jklprogressbar,'mno':self.ctw2mnoprogressbar,'pqr':self.ctw2pqrprogressbar,'stuv':self.ctw2stuvprogressbar,'wxyz':self.ctw2wxyzprogressbar}
            self.optionallabel={'abc':self.ctw2abclabel1,'def':self.ctw2deflabel1,'ghi':self.ctw2ghilabel1,'jkl':self.ctw2jkllabel1,'mno':self.ctw2mnolabel1,'pqr':self.ctw2pqrlabel_2,'stuv':self.ctw2stuvlabel1,'wxyz':self.ctw2wxyzlabel_2}     
            f = open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv','w')
            f.truncate()
            f.close()
            with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'a') as f:
                    writer = csv.writer(f)
                    writer.writerow([str(self.ctwrandnum[self.number2cont])])
            self.stackedWidget.setCurrentIndex(3)
    #         try:
    #             self.dtf=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listcorrect.csv',header=None,delimiter=',')
    #             progressBarDict['abc'].setValue(int((len(self.dtf[0])/selfsize)*100))
    #         except:
    #             progressBarDict['abc'].setValue(int(0))
            for i in self.progressBarDict:
                dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
                self.size=len(dtsizer[0])
                try:
                    self.dtf=pd.read_csv('ctw/save/'+i+'/'+i+'listcorrect.csv',header=None,delimiter=',')
                    dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
                    self.size=len(dtsizer[0])
                    self.optionallabel[i].setText(str(len(self.dtf[0]))+' of '+str(self.size)+' words completed')
                    self.progressBarDict[i].setValue(int((len(self.dtf[0])/self.size)*100))
                    if(int((len(self.dtf[0])/self.size)*100)==100):
                        self.ctwoptionalBut[i].setText('Replay again')
                        print('yes I am there')
                    else:
                        self.ctwoptionalBut[i].setText('Practice this Deck >')
                except:
                    self.progressBarDict[str(i)].setValue(int(0))
                    self.optionallabel[i].setText(str(0)+' of '+str(self.size)+' words completed')
        else:
            self.progressBarDict={'abc':self.ctw2abcprogressbar,'def':self.ctw2defprogressbar,'ghi':self.ctw2ghiprogressbar,'jkl':self.ctw2jklprogressbar,'mno':self.ctw2mnoprogressbar,'pqr':self.ctw2pqrprogressbar,'stuv':self.ctw2stuvprogressbar,'wxyz':self.ctw2wxyzprogressbar}

            self.stackedWidget.setCurrentIndex(3)
            print("ci"+str(self.stackedWidget.currentIndex()))
            self.optionallabel={'abc':self.ctw2abclabel1,'def':self.ctw2deflabel1,'ghi':self.ctw2ghilabel1,'jkl':self.ctw2jkllabel1,'mno':self.ctw2mnolabel1,'pqr':self.ctw2pqrlabel_2,'stuv':self.ctw2stuvlabel1,'wxyz':self.ctw2wxyzlabel_2}     
    #         try:
    #             self.dtf=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listcorrect.csv',header=None,delimiter=',')
    #             progressBarDict['abc'].setValue(int((len(self.dtf[0])/selfsize)*100))
    #         except:
    #             progressBarDict['abc'].setValue(int(0))
            for i in self.progressBarDict:
                dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
                self.size=len(dtsizer[0])
                try:
                    self.dtf=pd.read_csv('ctw/save/'+i+'/'+i+'listcorrect.csv',header=None,delimiter=',')
                    dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
                    self.size=len(dtsizer[0])
                    self.progressBarDict[i].setValue(int((len(self.dtf[0])/self.size)*100))
                    self.optionallabel[i].setText(str(len(self.dtf[0]))+' of '+str(self.size)+' words completed')
                    if(int((len(self.dtf[0])/self.size)*100)==100):
                        self.ctwoptionalBut[i].setText('Replay again')
                        print('yes I am there')
                    else:
                        self.ctwoptionalBut[i].setText('Practice this Deck >')
                except:
                    self.progressBarDict[str(i)].setValue(int(0))
                    self.optionallabel[i].setText(str(0)+' of '+str(self.size)+' words completed')
            
#                 print('except'+i)
    def back2home(self):
        self.stackedWidget.setCurrentIndex(2)
    def saveProgress(self):
        if(self.stackedWidget.currentIndex()==0):
            print('yes I am in SW 0')
            if(self.impindicator=='regular'):
            
                f = open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'w')
                f.truncate()
                f.close()
                with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'a') as f:
                    writer = csv.writer(f)
                    writer.writerow([str(self.ctwrandnum[self.number2cont])])
                
            else:
                pass
        else:
            pass  
#     def closeEvent(self,event):
#         result = QtGui.QMessageBox.question(self,
#                       "Confirm Exit...",
#                       "Are you sure you want to exit ?",
#                       QtGui.QMessageBox.Yes| QtGui.QMessageBox.No)
#         event.ignore()

#         if result == QtGui.QMessageBox.Yes:
#             event.accept()
#     def closed(self):
#         if(self.stackedWidget.currentIndex()==0):
#             if(self.impindicator=='regular'):
#                 result = QMessageBox.question(self,
#                           "Confirm Exit...",
#                           "Are you sure you want to exit ?",
#                           QMessageBox.Yes| QMessageBox.No)

#                 if(result == QMessageBox.Yes):
#                     event.accept()
#                     f = open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'w')
#                     f.truncate()
#                     f.close()
#                     with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'a') as f:
#                         writer = csv.writer(f)
#                         writer.writerow([str(self.ctwrandnum[self.number2cont])])
                            
#                 else:
#                     event.ignore()   
#             else:
#                 pass
#         else:
#             pass  

#     def closeEvent(self):
#         print('you pressde x')
#         obj=QtWidgets.QMainWindow()
#         reply = QMessageBox.question(obj, 'Message',
#                                      "Are you sure to quit?", QMessageBox.Yes |
#                                      QMessageBox.No, QMessageBox.No)
#         if reply == QMessageBox.Yes:
#             event.accept()
#         else:
#             event.ignore()

#     def closeEvent(self, event):
#         print('Closed')
#         if(self.stackedWidget.currentIndex()==0):
#             if(self.impindicator=='regular'):
#                 print('Closed if')
#                 obj=QtWidgets.QMainWindow()
#                 print('1 da')
#                 reply = QMessageBox.question(self, "Message","Are you sure you want to quit? Any unsaved work will be lost.",QMessageBox.Save | QMessageBox.Close | QMessageBox.Cancel,QMessageBox.Save)
#                 print('2 da')
#                 if(reply == QMessageBox.Close):
#                     event.accept()
#                 elif(reply==QMessageBox.Save):
#                     f = open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'w')
#                     f.truncate()
#                     f.close()
#                     with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'a') as f:
#                         writer = csv.writer(f)
#                         writer.writerow([str(self.ctwrandnum[self.number2cont])])
#                     event.accept()
#                 else:
#                     event.ignore()

#                 msgbox = QtWidgets.QMessageBox()
#                 msgbox.setWindowTitle("Information")
#                 msgbox.setText('Test')
#                 msgbox.addButton(QtWidgets.QMessageBox.Ok)
#                 save_button = msgbox.addButton('Save', QtWidgets.QMessageBox.YesRole)
#                 ret = msgbox.exec_()
#                 save_button.clicked.connect(self.save)    
#             else:
#                 print('Closed else')
#         else:
#             print('antha page illa')
#     def save(self):
#         f = open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'w')
#         f.truncate()
#         f.close()
#         with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'a') as f:
#             writer = csv.writer(f)
#             writer.writerow([str(self.ctwrandnum[self.number2cont])])
    def optionalselect(self):
        self.progressBarDict={'abc':self.ctw2abcprogressbar,'def':self.ctw2defprogressbar,'ghi':self.ctw2ghiprogressbar,'jkl':self.ctw2jklprogressbar,'mno':self.ctw2mnoprogressbar,'pqr':self.ctw2pqrprogressbar,'stuv':self.ctw2stuvprogressbar,'wxyz':self.ctw2wxyzprogressbar}    
        self.optionallabel={'abc':self.ctw2abclabel1,'def':self.ctw2deflabel1,'ghi':self.ctw2ghilabel1,'jkl':self.ctw2jkllabel1,'mno':self.ctw2mnolabel1,'pqr':self.ctw2pqrlabel_2,'stuv':self.ctw2stuvlabel1,'wxyz':self.ctw2wxyzlabel_2}     
        for i in self.progressBarDict:
            dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
            self.size=len(dtsizer[0])
            try:
                print(i+'start')
                
                self.dtf=pd.read_csv('ctw/save/'+i+'/'+i+'listcorrect.csv',header=None,delimiter=',')
                print('1')
                self.optionallabel[i].setText(str(len(self.dtf[0]))+' of '+str(self.size)+' words completed')
                dtsizer=pd.read_csv('ctw/save/'+i+'/'+i+'listnum.csv',header=None,delimiter=',')
                print('2')
                self.size=len(dtsizer[0])
                print('3')
                self.progressBarDict[i].setValue(int(((len(self.dtf[0])/int(self.size)))*100))
                print('4')
                print(int(((len(self.dtf[0])/int(self.size)))*100))
                print(i+'end')
                if(int((len(self.dtf[0])/self.size)*100)==100):
                    self.ctwoptionalBut[i].setText('Replay again')
                    print('yes I am there')
                else:
                    self.ctwoptionalBut[i].setText('Practice this Deck >')
            except:
                print(i+'except')
                self.progressBarDict[str(i)].setValue(int(0))
                self.optionallabel[i].setText(str(0)+' of '+str(self.size)+' words completed')
        self.stackedWidget.setCurrentIndex(3)
        print("ci"+str(self.stackedWidget.currentIndex()))
    def nav2stf(self):
        self.stackedWidget.setCurrentIndex(1)
        self.scorenum=0
        self.stfqnum=1
        self.stfprogress()
    def stfprogress(self):
#         self.stfindicator.setHidden(False)
        self.gif =QMovie('thinking_mod.gif')
        self.stfindicator.setMovie(self.gif)
        self.gif.start()
        self.stfqnumLabel.setText(str(self.stfqnum))
        self.fauna_rand_num=randint(1,20)
        self.stfpresent=self.fauna_list[self.fauna_rand_num-1]
        self.stfimageLabel.setPixmap(QtGui.QPixmap("E:/images clipart/fauna/"+str(self.fauna_rand_num)+".jpg"))
        self.dictof={}
        alphabets = string.ascii_lowercase
        counter=0
        random.shuffle(self.stfbuttonlist)
        for i in range(len(self.stfbuttonlist)-len(self.stfpresent)):
            icon2 = QtGui.QIcon()
            icon2.addPixmap(QtGui.QPixmap("E:/images clipart/letters/"+str(alphabets[counter])+".png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
            self.stfbuttonlist[i].setIcon(icon2)
            self.stfbuttonlist[i].setIconSize(QtCore.QSize(40, 40))
            self.dictof.__setitem__(str(self.stfbuttonlist[i]),str(alphabets[counter])) 
            counter=counter+1
            if(counter==25):
                counter=0
        ind=len(self.stfbuttonlist)-len(self.stfpresent)
        counter=0
        for j in range(ind,len(self.stfbuttonlist)):
            icon2 = QtGui.QIcon()
            icon2.addPixmap(QtGui.QPixmap("E:/images clipart/letters/"+str(self.stfpresent[counter])+".png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
            self.stfbuttonlist[j].setIcon(icon2)
            self.stfbuttonlist[j].setIconSize(QtCore.QSize(40, 40))
            self.dictof.__setitem__(str(self.stfbuttonlist[j]),str(self.stfpresent[counter])) 
            counter=counter+1
        self.stfLineedit.setText('')
        self.ptfcheckButton.setEnabled(True)
        self.stfqnum+=1
        for i in self.clicked_order_list:
            i.setEnabled(True)
        self.clicked_order_list=[]
#         self.stfindicator.setHidden(True)
        self.label.setHidden(True)
    def alphaclicked(self):
        self.clickedbut=self.MainWindow.sender()
        self.stfLineedit.insert(self.dictof[str(self.clickedbut)])
        self.clicked_order_list.append(self.clickedbut)
        self.clickedbut.setEnabled(False)
    def backspace(self):
        self.stfLineedit.backspace()
        self.clicked_order_list[-1].setEnabled(True)
        self.clicked_order_list.remove(self.clicked_order_list[-1])
    def stfcheck(self):
#         self.stfindicator.setHidden(False)
        self.label.setHidden(False)
        if(self.stfLineedit.text()==self.stfpresent):
            self.gif =QMovie('thumbsup_mod.gif')
            self.stfindicator.setMovie(self.gif)
            self.gif.start()
            self.scorenum+=1
            self.stfscoreLabel.setText('SCORE: '+str(self.scorenum))
            self.label.setText('Correct')
        else:
            self.gif =QMovie('thumbsdown_mod.gif')
            self.stfindicator.setMovie(self.gif)
            self.gif.start()
            self.label.setText('Answer is '+str(self.stfpresent))
        self.ptfcheckButton.setEnabled(False)
    def stfhint(self):
        engine1 = pyttsx3.init()
        engine1.setProperty('rate', 100)
        engine1.setProperty('volume', 1)
        engine1.say(self.stfpresent)
        engine1.runAndWait()
    def navigate2ctw(self):
        print("ci"+str(self.stackedWidget.currentIndex()))
        self.magooshsender=self.MainWindow.sender()
        self.filename=str(self.magooshsender.objectName())
        self.chosen=self.filename.replace('button','')
        self.chosen=self.chosen.replace('ctw2','')
        print(self.chosen)
        if(self.ctwoptionalBut[self.chosen].text()=='Replay again'):
            f = open('ctw/save/'+str(self.chosen)+'/'+'indicator.csv', 'w')
            f.truncate()
            f.close()
            with open('ctw/save/'+str(self.chosen)+'/'+'indicator.csv', 'a') as f:
                writer = csv.writer(f)
                writer.writerow([str('regular')])
            f = open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listcorrect.csv', 'w')
            f.truncate()
            f.close()
            f = open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'w')
            f.truncate()
            f.close()
            with open('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv', 'a') as f:
                writer = csv.writer(f)
                writer.writerow([str(0)])
            df=pd.read_csv( 'ctw/'+self.chosen+ '.csv',header=None,delimiter=',')

            self.words_arr=list(df[0])
            print('...')
            print(len(self.words_arr))
            print('....')
            self.ctwrandnum=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listnum.csv',header=None,delimiter=',')
            self.ctwrandnum=list(self.ctwrandnum[0])
    #         self.size=len(self.ctwrandnum)
            self.stackedWidget.setCurrentIndex(0)
            self.qnum=0
            self.score=0
            self.scoreLabel.setText('SCORE: 0')
            dflast=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv',header=None,delimiter=',')
            self.lastnumlasttime=dflast[0][0]
            self.number2cont=self.ctwrandnum.index(self.lastnumlasttime)
            dfindicator=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+'indicator.csv',header=None,delimiter=',')
            self.impindicator=dfindicator[0][0]
    #         self.progressBarDict={'abc':self.ctw2abcprogressbar,'def':self.ctw2defprogressbar,'ghi':self.ctw2ghiprogressbar,'jkl':self.ctw2jklprogressbar,'mno':self.ctw2mnoprogressbar,'pqr':self.ctw2pqrprogressbar,'stuv':self.ctw2stuvprogressbar,'wxyz':self.ctw2wxyzprogressbar}

    #           for i in self.progressBarDict:
    #             try:
    #                 self.dtf=pd.read_csv('ctw/save/'+i+'/'+i+'listcorrect.csv',header=None,delimiter=',')
    #                 self.progressBarDict[i].setValue(int((len(self.dtf[0])/self.size)*100))
    #             except:
    #                 self.progressBarDict[str(i)].setValue(int(0))

            self.starter()
        else:
            df=pd.read_csv( 'ctw/'+self.chosen+ '.csv',header=None,delimiter=',')
        
            self.words_arr=list(df[0])
            print('...')
            print(len(self.words_arr))
            print('....')
            self.ctwrandnum=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listnum.csv',header=None,delimiter=',')
            self.ctwrandnum=list(self.ctwrandnum[0])
    #         self.size=len(self.ctwrandnum)
            self.stackedWidget.setCurrentIndex(0)
            self.qnum=0
            self.score=0
            self.scoreLabel.setText('SCORE: 0')
            dflast=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+str(self.chosen)+'listlastnum.csv',header=None,delimiter=',')
            self.lastnumlasttime=dflast[0][0]
            self.number2cont=self.ctwrandnum.index(self.lastnumlasttime)
            dfindicator=pd.read_csv('ctw/save/'+str(self.chosen)+'/'+'indicator.csv',header=None,delimiter=',')
            self.impindicator=dfindicator[0][0]
    #         self.progressBarDict={'abc':self.ctw2abcprogressbar,'def':self.ctw2defprogressbar,'ghi':self.ctw2ghiprogressbar,'jkl':self.ctw2jklprogressbar,'mno':self.ctw2mnoprogressbar,'pqr':self.ctw2pqrprogressbar,'stuv':self.ctw2stuvprogressbar,'wxyz':self.ctw2wxyzprogressbar}

    #           for i in self.progressBarDict:
    #             try:
    #                 self.dtf=pd.read_csv('ctw/save/'+i+'/'+i+'listcorrect.csv',header=None,delimiter=',')
    #                 self.progressBarDict[i].setValue(int((len(self.dtf[0])/self.size)*100))
    #             except:
    #                 self.progressBarDict[str(i)].setValue(int(0))

            self.starter()
    def abouttheapp(self):
        QMessageBox.information(QtWidgets.QWidget(),'About',"<html><head><meta name=\"qrichtext\" content=\"1\" /><style type=\"text/css\">\n"
"p, li { white-space: pre-wrap; }\n"
"</style></head><body style=\" font-family:\'Vani\'; font-size:8.25pt; font-weight:400; font-style:normal;\">\n"
"<p align=\"center\" style=\" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;\"><span style=\" font-family:\'MS Shell Dlg 2\'; font-size:14pt; font-weight:600; text-decoration: underline; color:#00007f;\">Flair 4 Words</span></p>\n"
"<p align=\"center\" style=\"-qt-paragraph-type:empty; margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px; font-family:\'MS Shell Dlg 2\'; font-size:14pt; font-weight:600; text-decoration: underline; color:#00007f;\"><br /></p>\n"
"<p align=\"justify\" style=\" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;\"><span style=\" font-family:\'MS Shell Dlg 2\'; font-size:12pt; font-weight:600; text-decoration: underline;\">Motif</span><span style=\" font-family:\'MS Shell Dlg 2\'; font-size:12pt; font-weight:600;\"> - </span><span style=\" font-family:\'MS Shell Dlg 2\'; font-size:12pt;\">This application was developed to magnify the learning ability of dyslexic children by teaching through feasible ways.</span></p>\n"
"<p align=\"justify\" style=\"-qt-paragraph-type:empty; margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px; font-family:\'MS Shell Dlg 2\'; font-size:12pt; font-weight:600;\"><br /></p>\n"
"<p align=\"justify\" style=\" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;\"><span style=\" font-family:\'MS Shell Dlg 2\'; font-size:12pt; font-weight:600; text-decoration: underline;\">About app</span><span style=\" font-family:\'MS Shell Dlg 2\'; font-size:12pt; font-weight:600;\"> - </span><span style=\" font-family:\'MS Shell Dlg 2\'; font-size:12pt;\">This app holds two sections, one for practicing spellings of 3000 most common words and another for perceiving the shape of alphabets that make up the given word from a bunch.</span></p>\n"
"<p align=\"justify\" style=\"-qt-paragraph-type:empty; margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px; font-family:\'MS Shell Dlg 2\'; font-size:12pt; font-weight:600;\"><br /></p>\n")

# class MyWindow(QtWidgets.QMainWindow):
#     def closeEvent(self,event):
#         myclass=Ui_MainWindow()
#         myclass.closed()
class MyWindow(QtWidgets.QMainWindow):
    def closeEvent(self,event):
        result = QMessageBox.question(self,
                      "Confirm Exit...",
                      "Are you sure you want to exit ?",
                      QMessageBox.Yes| QMessageBox.No)
        event.ignore()

        if result == QMessageBox.Yes:
            event.accept()
